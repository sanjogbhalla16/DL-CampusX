# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ushape.csv')

# %%
df.head()
# Out:
#    3.159499363321345566e-02  9.869877579082642072e-01  \
# 0                  2.115098                 -0.046244
# 1                  0.882490                 -0.075756
# 2                 -0.055144                 -0.037332
# 3                  0.829545                 -0.539321
# 4                  2.112857                  0.662084
#
#    0.000000000000000000e+00
# 0                       1.0
# 1                       0.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %%
df['X'] = df['3.159499363321345566e-02']
df['Y'] = df['9.869877579082642072e-01']
df['class'] = df['0.000000000000000000e+00']

# %%
df.drop(['3.159499363321345566e-02', '9.869877579082642072e-01', '0.000000000000000000e+00'], axis=1, inplace=True)

# %%
df.head()
# Out:
#           X         Y  class
# 0  2.115098 -0.046244    1.0
# 1  0.882490 -0.075756    0.0
# 2 -0.055144 -0.037332    1.0
# 3  0.829545 -0.539321    1.0
# 4  2.112857  0.662084    1.0

# %%
plt.scatter(x = df['X'], y = df['Y'], c=df['class'])

# %%
X = df.iloc[:, 0:2].values
y = df.iloc[:, -1].values

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2, activation='sigmoid',input_dim=2))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#Set parameters to zero

model.get_weights()
# Out:
# [array([[0.37120402, 1.1082546 ],
#         [1.063347  , 0.08509231]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-1.1122708 ],
#         [ 0.31739843]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights = model.get_weights()

# %%
initial_weights[0] = np.zeros(initial_weights[0].shape)
initial_weights[1] = np.zeros(initial_weights[1].shape)
initial_weights[2] = np.zeros(initial_weights[2].shape)
initial_weights[3] = np.zeros(initial_weights[3].shape)

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X,y, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.4051 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6930 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5063 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5063 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5063 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5063 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6928
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6928
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6928
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5063 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5063 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5063 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5063 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6925
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.6925
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.6924
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.6924
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6924 - val_accuracy: 0.5000 - val_loss: 0.6923
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5063 - loss: 0.6923 - val_accuracy: 0.5000 - val_loss: 0.6922
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5063 - loss: 0.6923 - val_accuracy: 0.5000 - val_loss: 0.6921
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5063 - loss: 0.6922 - val_accuracy: 0.5000 - val_loss: 0.6920
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5063 - loss: 0.6922 - val_accuracy: 0.5000 - val_loss: 0.6920
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5063 - loss: 0.6921 - val_accuracy: 0.5000 - val_loss: 0.6919
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5063 - loss: 0.6920 - val_accuracy: 0.5000 - val_loss: 0.6918
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6919 - val_accuracy: 0.5000 - val_loss: 0.6917
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5063 - loss: 0.6918 - val_accuracy: 0.5000 - val_loss: 0.6916
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6918 - val_accuracy: 0.5000 - val_loss: 0.6915
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 0.6914
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6916 - val_accuracy: 0.5000 - val_loss: 0.6913
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6916 - val_accuracy: 0.5000 - val_loss: 0.6912
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6915 - val_accuracy: 0.5000 - val_loss: 0.6911
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6913 - val_accuracy: 0.5000 - val_loss: 0.6910
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5063 - loss: 0.6913 - val_accuracy: 0.5000 - val_loss: 0.6908
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6911 - val_accuracy: 0.5000 - val_loss: 0.6907
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5063 - loss: 0.6911 - val_accuracy: 0.5000 - val_loss: 0.6905
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6909 - val_accuracy: 0.5000 - val_loss: 0.6904
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5063 - loss: 0.6908 - val_accuracy: 0.5000 - val_loss: 0.6903
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6907 - val_accuracy: 0.5000 - val_loss: 0.6901
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5063 - loss: 0.6906 - val_accuracy: 0.5000 - val_loss: 0.6900
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5063 - loss: 0.6905 - val_accuracy: 0.5000 - val_loss: 0.6898
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5063 - loss: 0.6904 - val_accuracy: 0.5000 - val_loss: 0.6897
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5063 - loss: 0.6902 - val_accuracy: 0.5000 - val_loss: 0.6895
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5063 - loss: 0.6901 - val_accuracy: 0.5000 - val_loss: 0.6894
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5063 - loss: 0.6900 - val_accuracy: 0.5000 - val_loss: 0.6892
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5063 - loss: 0.6899 - val_accuracy: 0.5000 - val_loss: 0.6890
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6897 - val_accuracy: 0.5000 - val_loss: 0.6888
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5063 - loss: 0.6895 - val_accuracy: 0.5000 - val_loss: 0.6886
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6894 - val_accuracy: 0.5000 - val_loss: 0.6884
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6893 - val_accuracy: 0.5000 - val_loss: 0.6882
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5063 - loss: 0.6891 - val_accuracy: 0.5000 - val_loss: 0.6880
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6889 - val_accuracy: 0.5000 - val_loss: 0.6878
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5063 - loss: 0.6888 - val_accuracy: 0.5000 - val_loss: 0.6876
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5063 - loss: 0.6887 - val_accuracy: 0.5000 - val_loss: 0.6874
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5063 - loss: 0.6885 - val_accuracy: 0.5000 - val_loss: 0.6872
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6883 - val_accuracy: 0.5000 - val_loss: 0.6871
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5063 - loss: 0.6882 - val_accuracy: 0.5000 - val_loss: 0.6869
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5063 - loss: 0.6881 - val_accuracy: 0.5000 - val_loss: 0.6867
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6879 - val_accuracy: 0.5000 - val_loss: 0.6864
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6877 - val_accuracy: 0.5000 - val_loss: 0.6862
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5063 - loss: 0.6876 - val_accuracy: 0.5000 - val_loss: 0.6860
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6874 - val_accuracy: 0.5000 - val_loss: 0.6858
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5063 - loss: 0.6872 - val_accuracy: 0.5000 - val_loss: 0.6855
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5063 - loss: 0.6870 - val_accuracy: 0.5000 - val_loss: 0.6853
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5063 - loss: 0.6868 - val_accuracy: 0.5000 - val_loss: 0.6850
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6867 - val_accuracy: 0.5000 - val_loss: 0.6848
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5063 - loss: 0.6865 - val_accuracy: 0.5000 - val_loss: 0.6846
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5063 - loss: 0.6863 - val_accuracy: 0.5000 - val_loss: 0.6843
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5063 - loss: 0.6861 - val_accuracy: 0.5000 - val_loss: 0.6840
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5063 - loss: 0.6859 - val_accuracy: 0.5000 - val_loss: 0.6838
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6857 - val_accuracy: 0.5000 - val_loss: 0.6835
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5063 - loss: 0.6854 - val_accuracy: 0.5000 - val_loss: 0.6832
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5063 - loss: 0.6853 - val_accuracy: 0.5000 - val_loss: 0.6829
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6850 - val_accuracy: 0.5000 - val_loss: 0.6826
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5063 - loss: 0.6849 - val_accuracy: 0.5000 - val_loss: 0.6823
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6845 - val_accuracy: 0.5000 - val_loss: 0.6820
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5063 - loss: 0.6843 - val_accuracy: 0.5000 - val_loss: 0.6817

# %%
model.get_weights()
# Out:
# [array([[ 0.4529065 ,  0.4529065 ],
#         [-0.48405033, -0.48405033]], dtype=float32),
#  array([-0.06687152, -0.06687152], dtype=float32),
#  array([[0.10904232],
#         [0.10904232]], dtype=float32),
#  array([-0.01939356], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X, y.astype('int'), clf=model, legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step
# <Axes: >
